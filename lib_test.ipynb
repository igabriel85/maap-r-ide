# %%
library(lasR)

# %%
library(lidR)

# %%
help(lasR)
# Out:
# lasR-package               package:lasR                R Documentation
#
# s
#
# n:
#
#      lasR provides a set of tools to process efficiently airborne LiDAR
#      data in forestry contexts. The package works with .las or .laz
#      files. The toolbox includes algorithms for DSM, CHM, DTM, ABA,
#      normalisation, tree detection, tree segmentation, tree
#      delineation, colourization, validation and other tools, as well as
#      a processing engine to process broad LiDAR coverage split into
#      many files efficiently.
#
# s):
#
#      *Maintainer*: Jean-Romain Roussel <mailto:info@r-lidar.com>
#      [copyright holder]
#
#      Other contributors:
#
#         • Martin Isenburg (Is the author of the included LASlib and
#           LASzip libraries) [copyright holder]
#
#         • Benoît St-Onge (Is the author of the included 'chm_prep'
#           function) [copyright holder]
#
#         • Niels Lohmann (Is the author of the included json parser)
# ...

# %%
help(lidR)
# Out:
# lidR-package               package:lidR                R Documentation
#
# s
#
# n:
#
#      lidR provides a set of tools to manipulate airborne LiDAR data in
#      forestry contexts. The package works with .las or .laz files. The
#      toolbox includes algorithms for DSM, CHM, DTM, ABA, normalisation,
#      tree detection, tree segmentation, tree delineation,
#      colourization, validation and other tools, as well as a processing
#      engine to process broad LiDAR coverage split into many files.
#
# s:
#
#      To learn more about lidR, start with the vignettes:
#      browseVignettes(package = "lidR"). Users can also find unofficial
#      supplementary documentation in the lidR book. To ask "how to"
#      questions please ask on gis.stackexchange.com with the tag ‘lidr’.
#
# s:
#
#      ‘lidR.progress’ Several functions have a progress bar for long
#           operations (but not all). Should lengthy operations show a
#           progress bar? Default: TRUE
#
# ...

# %%
str(allPackage <- installed.packages(.Library))
# Out:
#  chr [1:367, 1:16] "abind" "arrow" "askpass" "assertthat" "aws.s3" ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:367] "abind" "arrow" "askpass" "assertthat" ...
#   ..$ : chr [1:16] "Package" "LibPath" "Version" "Priority" ...

# %%
allPackage [, c(1,3:5)]
# Out:
#               Package       Version   Priority
# abind         abind         1.4-5     NA
# arrow         arrow         14.0.1    NA
# askpass       askpass       1.2.0     NA
# assertthat    assertthat    0.2.1     NA
# aws.s3        aws.s3        0.3.22    NA
# aws.signature aws.signature 0.6.0     NA
# backports     backports     1.5.0     NA
# base          base          4.2.3     base
# base64enc     base64enc     0.1-3     NA
# BH            BH            1.84.0-0  NA
# BiocManager   BiocManager   1.30.23   NA
# bit           bit           4.0.5     NA
# bit64         bit64         4.0.5     NA
# blob          blob          1.2.4     NA
# boot          boot          1.3-30    recommended
# brew          brew          1.0-10    NA
# brio          brio          1.1.5     NA
# broom         broom         1.0.6     NA
# bslib         bslib         0.7.0     NA
# cachem        cachem        1.1.0     NA
# callr         callr         3.7.6     NA
# ...
